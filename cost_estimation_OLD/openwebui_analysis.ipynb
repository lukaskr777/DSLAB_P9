# %% [markdown]
# # OPENWEBUI Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt

import glob

# %%
files = glob.glob("data/openwebui/public.function/1/*.parquet")  # adjust path
first_file = files[0]                # pick the first file
df = pd.read_parquet(first_file)
df.iloc[2]
# Out:
# id                                        schwizerdütsch_toggle
# user_id                    bc49bba7-3343-4f03-8601-a4c278228c24
# name                                     Schwiizerdütsch Toggle
# type                                                     filter
# content       from pydantic import BaseModel, Field\nfrom ty...
# meta          {"description": "Enables Swiss German response...
# created_at                                           1756683428
# updated_at                                           1756788131
# valves                                                     null
# is_active                                                  True
# is_global                                                 False
# Name: 2, dtype: object
